# %%
import requests
headers = {
    'authority': 'www.olx.in',
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9',
    'cache-control': 'no-cache',
    'dnt': '1',
    'pragma': 'no-cache',
    'referer': 'https://www.olx.in/items/q-hdfc-bank?isSearchCall=true',
    'sec-ch-ua': '"Not/A)Brand";v="99", "Google Chrome";v="115", "Chromium";v="115"',
    'sec-ch-ua-mobile': '?1',
    'sec-ch-ua-platform': '"Android"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Mobile Safari/537.36'
}
# serachquerry=
params = {
    'facet_limit': '100',
    'lang': 'en-IN',
    'location': '1000001',
    'location_facet_limit': '40',
    'page': '3',
    'platform': 'web-mobile',
    'query': 'hdfc bank',
    'relaxedFilters': 'true',
    'spellcheck': 'true',
}

response = requests.get('https://www.olx.in/api/relevance/v4/search', params=params,headers=headers )
data=response.json()

# %%
description = data['data'][0]['description']
# ownnerName = data['data'][1]['description']
print(description)
# Out:
# Dear candidate job available in hdfc bank. Get a big offer
#
# Designation-
#
# helper-: 12,860/-
#
# Enqury-: 16490/-
#
# cashier-: 18,960/-
#
# computer operator-:21160
#
# Clerk-:22,790/-
#
# loan officer: 24,360/-
#
# ABM-26,989/-
#
# Duty Hours- Banking Hours
#
# Candidate Criteria: Qualification-8th, 10th, 12th, Graduation and post graduation
#
# Age-18 to 40 Years,No Age Limit for Experience
#
# Experience-0-5yrs
#
# Location- near branch
#
# CONTACT MR. Mukesh kumar

# %%
# Out:
# {'version': '100.0', 'data': [{'id': '1739112893', 'score': 0.9608610567514677, 'spell': {'id': 111, 'key': 'GEAS_ES', 'version': '1', 'main': True, 'facet_disabled': False, 'default_sorting': 'DEFAULT'}, 'status': {'status': 'active', 'allow_edit': True, 'ban_reason_id': None, 'display': 'active', 'translated_display': 'Active', 'link': None, 'flags': {'new': False, 'hot': False}, 'message': None, 'allow_deactivate': True}, 'category_id': '62', 'ad_id': '1739112893', 'favorites': {'count': 0, 'count_label_next': '1'}, 'has_phone_param': False, 'description': 'Dear candidate job available in hdfc bank. Get a big offer\n\nDesignation-\n\nhelper-: 12,860/-\n\nEnqury-: 16490/-\n\ncashier-: 18,960/-\n\ncomputer operator-:21160\n\nClerk-:22,790/-\n\nloan officer: 24,360/-\n\nABM-26,989/-\n\nDuty Hours- Banking Hours\n\nCandidate Criteria: Qualification-8th, 10th, 12th, Graduation and post graduation\n\nAge-18 to 40 Years,No Age Limit for Experience\n\nExperience-0-5yrs\n\nLocation- near b
# ...

# %%
print(response.json())
# Out:
# {'version': '100.0', 'data': [{'id': '1739112893', 'score': 0.9608610567514677, 'spell': {'id': 111, 'key': 'GEAS_ES', 'version': '1', 'main': True, 'facet_disabled': False, 'default_sorting': 'DEFAULT'}, 'status': {'status': 'active', 'allow_edit': True, 'ban_reason_id': None, 'display': 'active', 'translated_display': 'Active', 'link': None, 'flags': {'new': False, 'hot': False}, 'message': None, 'allow_deactivate': True}, 'category_id': '62', 'ad_id': '1739112893', 'favorites': {'count': 0, 'count_label_next': '1'}, 'has_phone_param': False, 'description': 'Dear candidate job available in hdfc bank. Get a big offer\n\nDesignation-\n\nhelper-: 12,860/-\n\nEnqury-: 16490/-\n\ncashier-: 18,960/-\n\ncomputer operator-:21160\n\nClerk-:22,790/-\n\nloan officer: 24,360/-\n\nABM-26,989/-\n\nDuty Hours- Banking Hours\n\nCandidate Criteria: Qualification-8th, 10th, 12th, Graduation and post graduation\n\nAge-18 to 40 Years,No Age Limit for Experience\n\nExperience-0-5yrs\n\nLocation- near b
# ...

# %%
import requests

cookies = {
    'laquesisff': 'pan-36788#pan-38000#pan-42665#road-70737',
    'lqstatus': '1690482649',
    'bm_sz': '6205E93C638A92C41F89AAD1741EE7C8~~3223877~3290673',
    'relevanceUser': '02986550988029826',
    '_exponea_etc_': 'fb1c2783-a38f-48d6-854a-045ba133f428',
    '_exponea_time2_': '-0.3527412414550781',
    '_ga': 'GA1.2.900095110.1690481522',
    '_gid': 'GA1.2.392814379.1690481522',
    '_gcl_au': '1.1.29945357.1690481522',
    'WZRK_G': '46dfdabb218d40f1ac4bbb7eaa3c3050',
    '__gads': 'ID=1699ddf8b9acf18d:T=1690481523:RT=1690481523:S=ALNI_Mb2Rt2o7s9rESqI6uCcrgwQiHqN9Q',
    '__gpi': 'UID=00000c24b4c5bff0:T=1690481523:RT=1690481523:S=ALNI_MaDBe-jhkr59jtX3d5MSyq1xJgzSw',
    '_fbp': 'fb.1.1690481526130.742922893',
    'pbjs_debug': '0',
    'AMP_TOKEN': '%24NOT_FOUND',
    '_cc_id': 'ef995a97e4b2ae218fc0cd59ac8eca43',
    'panoramaId_expiry': '1690567926556',
    'clever-last-tracker-69087': '1',
    '_pbjs_userid_consent_data': '3524755945110770',
    'ak_bmsc': '1F911AC6A6704FA5C8CB74AC022E5AC8~000000000000000000000000000000~...',
    '_abck': '8290B4F7379ECAF161661BC22DD40AC4~0~...-1||-1||~-1',
    'testCookie': 'testCookie',
    'bm_sv': 'E6EF8D925973AF73C788EC30FBD18BF5~~1',
    'HIDE_ONBOARDING_LOCATION': 'true',
    'LANGUAGE_ONBOARDING_VIEW_COUNT': '1',
    '_uetsid': '17fe2be02ca911ee8b1019ce59af7be4',
    '_uetvid': '17fec5902ca911eea3a0a1c31ddb1e59',
    'cto_bundle': 'Tx4jLV8lMkI2Q1dvTlNKMDZpamxBSWd1RW5NaHRnbEJvMG5VMDJzMWUyTGczc3RIZTBzTHljUVJxa0RGTzA4MW5vNENUNHBDRkM5JTJGY250U2FLcFZrJTJCWSUyQmNqZFZnNnhsR1hVVVhVSHRXZldkMEsxQlRKMFVPb3dIYU12ZlFkdEdRd05hZ0V2TVY1aFE0NjZRSGhVNyUyQlV5Q2hDVkhRJTNEJTNE',
    '_ga_YQFV9HRDXQ': 'GS1.2.1690481527.1.1.1690481647.60.0.0',
    'WZRK_S_848-646-995Z': '%7B%22p%22%3A2%2C%22s%22%3A1690481524%2C%22t%22%3A1690481752%7D',
    '_hjSessionUser_1193424': 'eyJpZCI6ImNjMDNhNDQ5LWIwN2EtNWVjOC05ZDY5LWVkMTQ3MmRmYmFkOCIsImNyZWF0ZWQiOjE2OTA0ODE3NjA2NTYsImV4aXN0aW5nIjpmYWxzZX0=',
    '_hjFirstSeen': '1',
    '_hjIncludedInSessionSample_1193424': '1',
    '_hjSession_1193424': 'eyJpZCI6IjI2YWVhODBjLTQ0NTQtNDI0NC1iZmE5LTQzODI5NjZiNTUzOCIsImNyZWF0ZWQiOjE2OTA0ODE3NjA3MTIsImluU2FtcGxlIjp0cnVlfQ==',
    'onap': '189988cc09fx451cf8be-1-189988cc09fx451cf8be-12-1690483561',
}

headers = {
    'authority': 'www.olx.in',
    'accept': '/',
    'accept-language': 'en-US,en;q=0.9',
    'cache-control': 'no-cache',
    # 'cookie': 'laquesisff=pan-36788#pan-38000#pan-42665#road-70737; lqstatus=1690482649; bm_sz=6205E93C638A92C41F89AAD1741EE7C8~3223877~3290673; relevanceUser=02986550988029826; _exponea_etc=fb1c2783-a38f-48d6-854a-045ba133f428; __exponea_time2_=-0.3527412414550781; _ga=GA1.2.900095110.1690481522; _gid=GA1.2.392814379.1690481522; _gcl_au=1.1.29945357.1690481522; WZRK_G=46dfdabb218d40f1ac4bbb7eaa3c3050; __gads=ID=1699ddf8b9acf18d:T=1690481523:RT=1690481523:S=ALNI_Mb2Rt2o7s9rESqI6uCcrgwQiHqN9Q; __gpi=UID=00000c24b4c5bff0:T=1690481523:RT=1690481523:S=ALNI_MaDBe-jhkr59jtX3d5MSyq1xJgzSw; _fbp=fb.1.1690481526130.742922893; pbjs_debug=0; AMP_TOKEN=%24NOT_FOUND; _cc_id=ef995a97e4b2ae218fc0cd59ac8eca43; panoramaId_expiry=1690567926556; clever-last-tracker-69087=1; _pbjs_userid_consent_data=3524755945110770; ak_bmsc=1F911AC6A6704FA5C8CB74AC022E5AC8~000000000000000000000000000000~...; _abck=8290B4F7379ECAF161661BC22DD40AC4~0~...-1~||-1||~-1; testCookie=testCookie; bm_sv=E6EF8D925973AF73C788EC30FBD18BF5~~1; HIDE_ONBOARDING_LOCATION=true; LANGUAGE_ONBOARDING_VIEW_COUNT=1; _uetsid=17fe2be02ca911ee8b1019ce59af7be4; _uetvid=17fec5902ca911eea3a0a1c31ddb1e59; cto_bundle=Tx4jLV8lMkI2Q1dvTlNKMDZpamxBSWd1RW5NaHRnbEJvMG5VMDJzMWUyTGczc3RIZTBzTHljUVJxa0RGTzA4MW5vNENUNHBDRkM5JTJGY250U2FLcFZrJTJCWSUyQmNqZFZnNnhsR1hVVVhVSHRXZldkMEsxQlRKMFVPb3dIYU12ZlFkdEdRd05hZ0V2TVY1aFE0NjZRSGhVNyUyQlV5Q2hDVkhRJTNEJTNE; _ga_YQFV9HRDXQ=GS1.2.1690481527.1.1.1690481647.60.0.0; WZRK_S_848-646-995Z=%7B%22p%22%3A2%2C%22s%22%3A1690481524%2C%22t%22%3A1690481752%7D; _hjSessionUser_1193424=eyJpZCI6ImNjMDNhNDQ5LWIwN2EtNWVjOC05ZDY5LWVkMTQ3MmRmYmFkOCIsImNyZWF0ZWQiOjE2OTA0ODE3NjA2NTYsImV4aXN0aW5nIjpmYWxzZX0=; _hjFirstSeen=1; _hjIncludedInSessionSample_1193424=1; _hjSession_1193424=eyJpZCI6IjI2YWVhODBjLTQ0NTQtNDI0NC1iZmE5LTQzODI5NjZiNTUzOCIsImNyZWF0ZWQiOjE2OTA0ODE3NjA3MTIsImluU2FtcGxlIjp0cnVlfQ==; onap=189988cc09fx451cf8be-1-189988cc09fx451cf8be-12-1690483561',
    'dnt': '1',
    'pragma': 'no-cache',
    'referer': 'https://www.olx.in/items/q-hdfc-bank?isSearchCall=true',
    'sec-ch-ua': '"Not/A)Brand";v="99", "Google Chrome";v="115", "Chromium";v="115"',
    'sec-ch-ua-mobile': '?1',
    'sec-ch-ua-platform': '"Android"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Mobile Safari/537.36',
    'x-newrelic-id': 'VQMGU1ZVDxABU1lbBgMDUlI=',
    'x-panamera-fingerprint': '2c9d2707ae34bece19ea0229ec9caede#1690481521319',
}

params = {
    'facet_limit': '100',
    'lang': 'en-IN',
    'location': '1000001',
    'location_facet_limit': '20',
    'page': '1',
    'platform': 'web-mobile',
    'query': 'hdfc bank',
    'relaxedFilters': 'true',
    'spellcheck': 'true',
    'user': '189988cc09fx451cf8be',
}

response = requests.get('https://www.olx.in/api/relevance/v4/search', params=params, cookies=cookies, headers=headers)

# %%
print(response)
data=response.json()
description = data['data'][0]['description']
# ownnerName = data['data'][1]['description']
print(description)
# Out:
# <Response [400]>
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# C:\Python39\lib\site-packages\requests\models.py in json(self, **kwargs)
#     970         try:
# --> 971             return complexjson.loads(self.text, **kwargs)
#     972         except JSONDecodeError as e:
#
# C:\Python39\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#
# C:\Python39\lib\json\decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# C:\Python39\lib\json\decoder.py in raw_decode(self, s, idx)
#     354         except StopIteration as err:
# ...
